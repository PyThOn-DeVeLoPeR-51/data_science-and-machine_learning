# %%
import pandas as pd

# %%
names = pd.Series(['Nodir', 'Sardor', 'Komil', 'Zokir'])
names
# Out:
# 0     Nodir
# 1    Sardor
# 2     Komil
# 3     Zokir
# dtype: object

# %%
names.values
# Out:
# array(['Nodir', 'Sardor', 'Komil', 'Zokir'], dtype=object)

# %%
names.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
names.name = 'NAMES'
names.index.name = 'INDEX'
names
# Out:
# INDEX
# 0     Nodir
# 1    Sardor
# 2     Komil
# 3     Zokir
# Name: NAMES, dtype: object
