# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(['Andijon', 'Buxoro', 'Farg\'ona', 'Jizzax', 'Xorazm', 'Namangan', 'Navoiy', 'Qashqadaryo', "Qoraqalpog\'iston Respublikasi", 'Samarqand', 'Sirdaryo', 'Surxondaryo', 'Toshkent'])
ser
# Out:
# 0                           Andijon
# 1                            Buxoro
# 2                          Farg'ona
# 3                            Jizzax
# 4                            Xorazm
# 5                          Namangan
# 6                            Navoiy
# 7                       Qashqadaryo
# 8     Qoraqalpog'iston Respublikasi
# 9                         Samarqand
# 10                         Sirdaryo
# 11                      Surxondaryo
# 12                         Toshkent
# dtype: object

# %%
len(ser)
# Out:
# 13

# %%
ser.values
# Out:
# array(['Andijon', 'Buxoro', "Farg'ona", 'Jizzax', 'Xorazm', 'Namangan',
#        'Navoiy', 'Qashqadaryo', "Qoraqalpog'iston Respublikasi",
#        'Samarqand', 'Sirdaryo', 'Surxondaryo', 'Toshkent'], dtype=object)

# %%
ser[0]
# Out:
# 'Andijon'

# %%
ser.iloc[-1]
# Out:
# 'Toshkent'

# %%
ser.size
# Out:
# 13

# %%
ser[[5, 6, 7]]
# Out:
# 5       Namangan
# 6         Navoiy
# 7    Qashqadaryo
# dtype: object

# %%
dict = {
    "Andijon": 4200,
    "Buxoro": 39400,
    "Farg'ona": 6800,
    "Jizzax": 20500,
    "Xorazm": 6300,
    "Namangan": 7900,
    "Navoiy": 110800,
    "Qashqadaryo": 28400,
    "Qoraqalpog'iston Respublikasi": 160000,
    "Samarqand": 16400,
    "Sirdaryo": 5100,
    "Surxondaryo": 20800,
    "Toshkent": 15300,
}
area = pd.Series(dict)
area
# Out:
# Andijon                            4200
# Buxoro                            39400
# Farg'ona                           6800
# Jizzax                            20500
# Xorazm                             6300
# Namangan                           7900
# Navoiy                           110800
# Qashqadaryo                       28400
# Qoraqalpog'iston Respublikasi    160000
# Samarqand                         16400
# Sirdaryo                           5100
# Surxondaryo                       20800
# Toshkent                          15300
# dtype: int64

# %%
print(f"Eng katta hudud: {area.idxmax()}")
print(f"Eng kichik hudud: {area.idxmin()}")
# Out:
# Eng katta hudud: Qoraqalpog'iston Respublikasi
# Eng kichik hudud: Andijon

# %%
print(f"{area.idxmax()} aholisi {area[area.idxmax()]}")
print(f"{area.idxmin()} aholisi {area[area.idxmin()]}")
# Out:
# Qoraqalpog'iston Respublikasi aholisi 160000
# Andijon aholisi 4200
