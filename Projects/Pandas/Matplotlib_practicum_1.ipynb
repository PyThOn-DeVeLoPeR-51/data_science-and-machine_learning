# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import ssl

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
data = pd.read_html("https://en.tutiempo.net/climate/ws-384570.html")
data[0]
# Out:
#     Year     T    TM    Tm PP    V   RA  SN  TS  FG TN GR
# 0   1933     -     -     -  -    -    -   -   -   -  -  -
# 1   1934     -     -     -  -    -    -   -   -   -  -  -
# 2   1935     -     -     -  -    -    -   -   -   -  -  -
# 3   1936     -     -     -  -    -    -   -   -   -  -  -
# 4   1937     -     -     -  -    -    -   -   -   -  -  -
# ..   ...   ...   ...   ... ..  ...  ...  ..  ..  .. .. ..
# 76  2020  15.5  21.3   9.2  -  9.8   92  37  18  26  0  0
# 77  2021    17  23.4  10.1  -   10   82  11  10  14  0  0
# 78  2022  16.7  22.6  10.2  -  9.8  115  17  14  32  0  0
# 79  2023  17.3  23.6  10.4  -   10   96  15  14  19  0  0
# 80  2024     -     -     -  -    -    -   -   -   -  -  -
#
# [81 rows x 12 columns]

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    Year  T TM Tm PP  V RA SN TS FG TN GR
# 0  1933  -  -  -  -  -  -  -  -  -  -  -
# 1  1934  -  -  -  -  -  -  -  -  -  -  -
# 2  1935  -  -  -  -  -  -  -  -  -  -  -
# 3  1936  -  -  -  -  -  -  -  -  -  -  -
# 4  1937  -  -  -  -  -  -  -  -  -  -  -

# %%
df.columns.values
# Out:
# array(['Year', 'T', 'TM', 'Tm', 'PP', 'V', 'RA', 'SN', 'TS', 'FG', 'TN',
#        'GR'], dtype=object)

# %%
df = df[df['Year']>1990]
df.head()
# Out:
#     Year     T    TM   Tm      PP    V  RA  SN  TS  FG TN GR
# 47  1991  14.4  21.2  8.3  460.52  5.1  77  26  15  17  0  1
# 48  1992  14.4  20.8  8.6  470.39  5.1  93  19   9   2  0  1
# 49  1993  13.4  19.6  7.6  710.97  5.4  98  38  12  10  1  0
# 50  1994  14.4  21.1    8  595.38  5.1  66  28   4   9  0  0
# 51  1995    15  22.2  8.4  189.99  4.4  41  20   8  12  0  0

# %%
 df.set_index('Year', inplace=True)
 df.head()
# Out:
#          T    TM   Tm      PP    V  RA  SN  TS  FG TN GR
# Year
# 1991  14.4  21.2  8.3  460.52  5.1  77  26  15  17  0  1
# 1992  14.4  20.8  8.6  470.39  5.1  93  19   9   2  0  1
# 1993  13.4  19.6  7.6  710.97  5.4  98  38  12  10  1  0
# 1994  14.4  21.1    8  595.38  5.1  66  28   4   9  0  0
# 1995    15  22.2  8.4  189.99  4.4  41  20   8  12  0  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 1991 to 2024
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       34 non-null     object
#  1   TM      34 non-null     object
#  2   Tm      34 non-null     object
#  3   PP      34 non-null     object
#  4   V       34 non-null     object
#  5   RA      34 non-null     object
#  6   SN      34 non-null     object
#  7   TS      34 non-null     object
#  8   FG      34 non-null     object
#  9   TN      34 non-null     object
#  10  GR      34 non-null     object
# dtypes: object(11)
# memory usage: 3.2+ KB

# %%
df = df.replace("-", np.nan)
df.head()
# Out:
#          T    TM   Tm      PP    V  RA  SN  TS  FG TN GR
# Year
# 1991  14.4  21.2  8.3  460.52  5.1  77  26  15  17  0  1
# 1992  14.4  20.8  8.6  470.39  5.1  93  19   9   2  0  1
# 1993  13.4  19.6  7.6  710.97  5.4  98  38  12  10  1  0
# 1994  14.4  21.1    8  595.38  5.1  66  28   4   9  0  0
# 1995    15  22.2  8.4  189.99  4.4  41  20   8  12  0  0

# %%
df = df.astype(dtype='float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 1991 to 2024
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       29 non-null     float64
#  1   TM      29 non-null     float64
#  2   Tm      29 non-null     float64
#  3   PP      9 non-null      float64
#  4   V       29 non-null     float64
#  5   RA      30 non-null     float64
#  6   SN      30 non-null     float64
#  7   TS      30 non-null     float64
#  8   FG      30 non-null     float64
#  9   TN      30 non-null     float64
#  10  GR      30 non-null     float64
# dtypes: float64(11)
# memory usage: 3.2 KB

# %%
df.head(10)
# Out:
#          T    TM   Tm      PP    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  460.52  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  470.39  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  710.97  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  595.38  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  189.99  4.4  41.0  20.0   8.0  12.0  0.0  0.0
# 1996  14.0  20.5  7.6  184.16  5.0  68.0  23.0  14.0  13.0  0.0  0.0
# 1997   NaN   NaN  NaN     NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 1998   NaN   NaN  NaN     NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 1999  15.7  22.4  8.9  524.21  7.6  98.0  15.0  13.0  18.0  0.0  0.0
# 2000  16.0  22.5  9.1     NaN  8.0  84.0  19.0  11.0  25.0  0.0  2.0

# %%
df.isnull().sum()/len(df)*100
# Out:
# T     14.705882
# TM    14.705882
# Tm    14.705882
# PP    73.529412
# V     14.705882
# RA    11.764706
# SN    11.764706
# TS    11.764706
# FG    11.764706
# TN    11.764706
# GR    11.764706
# dtype: float64

# %%
df.drop('PP', axis=1, inplace=True)
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
df = df.fillna(method = "ffill")
df.head()
# Out:
# <ipython-input-99-2604ee4c9b5c>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = "ffill")
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
df.to_csv("t_harorat.csv")

# %%
# plt.figure(figsize=(10,5))
x = df['T']
plt.title("Avarenge Temperature")
plt.plot(x)
plt.show()

# %%
# plt.figure(figsize=(18, 9))
x = df["T"]
plt.title("Average Temperature")
plt.xlabel('Years')
plt.ylabel("Temp")
plt.grid()
plt.plot(x, linewidth=2, linestyle="--", color="g", marker="h", markerfacecolor="r")
plt.show()

# %%
minT = df["Tm"]
maxT = df["TM"]
# plt.figure(figsize=(20, 10))
plt.title('Average Temperature of Tashkent')
plt.xlabel("Year")
plt.ylabel("Temp")
plt.grid()
plt.legend(["Average minimum temperature", "Average maximum temperature"], loc=2, fontsize="x-large")
plt.plot(minT, linewidth=2, linestyle="--", marker="h", markerfacecolor="g")
plt.plot(maxT, linewidth=2, linestyle="-", marker="v", markerfacecolor="r")
plt.savefig('tempMinMax.png')
plt.show()

# %%
from IPython.display import Image
Image("tempMinMax.png")
