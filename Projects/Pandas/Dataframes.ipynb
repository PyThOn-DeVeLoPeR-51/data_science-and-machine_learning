# %%
import pandas as pd

# %%
data = {
    'Yil': [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013],
    'Aholi soni': [33.9, 33.5, 32.9, 32.2, 31.8, 30.6, 30.1, 29.6, 29.2],
    'Temp': [1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53, 1.61]
}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.2  1.62
# 4  2017        31.8  1.65

# %%
df.shape
# Out:
# (9, 3)

# %%
df = pd.DataFrame(data, columns=['Aholi soni', 'Temp', 'Yil', 'YAIM'], index=[1, 2, 3, 4, 5, 6, 7, 8, 9])
df
# Out:
#    Aholi soni  Temp   Yil YAIM
# 1        33.9  1.54  2021  NaN
# 2        33.5  1.48  2020  NaN
# 3        32.9  1.56  2019  NaN
# 4        32.2  1.62  2018  NaN
# 5        31.8  1.65  2017  NaN
# 6        30.6  1.66  2016  NaN
# 7        30.1  1.64  2015  NaN
# 8        29.6  1.53  2014  NaN
# 9        29.2  1.61  2013  NaN

# %%
population = df['Aholi soni']
population
# Out:
# 1    33.9
# 2    33.5
# 3    32.9
# 4    32.2
# 5    31.8
# 6    30.6
# 7    30.1
# 8    29.6
# 9    29.2
# Name: Aholi soni, dtype: float64

# %%
df.Temp
# Out:
# 1    1.54
# 2    1.48
# 3    1.56
# 4    1.62
# 5    1.65
# 6    1.66
# 7    1.64
# 8    1.53
# 9    1.61
# Name: Temp, dtype: float64

# %%
df
# Out:
#    Aholi soni  Temp   Yil YAIM
# 1        33.9  1.54  2021  NaN
# 2        33.5  1.48  2020  NaN
# 3        32.9  1.56  2019  NaN
# 4        32.2  1.62  2018  NaN
# 5        31.8  1.65  2017  NaN
# 6        30.6  1.66  2016  NaN
# 7        30.1  1.64  2015  NaN
# 8        29.6  1.53  2014  NaN
# 9        29.2  1.61  2013  NaN

# %%
val = pd.Series([1750, 2000, 3750], index=[1, 5, 6])
df.YAIM = val
df
# Out:
#    Aholi soni  Temp   Yil    YAIM
# 1        33.9  1.54  2021  1750.0
# 2        33.5  1.48  2020     NaN
# 3        32.9  1.56  2019     NaN
# 4        32.2  1.62  2018     NaN
# 5        31.8  1.65  2017  2000.0
# 6        30.6  1.66  2016  3750.0
# 7        30.1  1.64  2015     NaN
# 8        29.6  1.53  2014     NaN
# 9        29.2  1.61  2013     NaN

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Incomes', 'YAIM', 'Aholi soni'])
df['Incomes'] = [5000000, 4500000, 4000000, 3700000, 3450000, 3100000, 2750000, 2400000, 2150000]
df.YAIM = val
df
# Out:
#     Yil  Temp  Incomes    YAIM  Aholi soni
# 0  2021  1.54  5000000     NaN        33.9
# 1  2020  1.48  4500000  1750.0        33.5
# 2  2019  1.56  4000000     NaN        32.9
# 3  2018  1.62  3700000     NaN        32.2
# 4  2017  1.65  3450000     NaN        31.8
# 5  2016  1.66  3100000  2000.0        30.6
# 6  2015  1.64  2750000  3750.0        30.1
# 7  2014  1.53  2400000     NaN        29.6
# 8  2013  1.61  2150000     NaN        29.2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Yil'].plot(kind='hist', bins=20, title='Yil')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Temp'].plot(kind='hist', bins=20, title='Temp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Incomes'].plot(kind='hist', bins=20, title='Incomes')
# ...

# %%
data1 = {
    'Uzbekistan': {2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan': {2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df1.index.name = 'Yil'
df1
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df1 = pd.DataFrame(data1, index=[2021, 2019, 2017])
df1
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df1.T
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
arr = df1.values
arr
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
type(arr)
# Out:
# numpy.ndarray
