# %%
import numpy as np

# %%
x = np.arange(1, 9).reshape(2, 4)
x
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
y = np.arange(9, 17).reshape(2, 4)
y
# Out:
# array([[ 9, 10, 11, 12],
#        [13, 14, 15, 16]])

# %%
x + y
# Out:
# array([[10, 12, 14, 16],
#        [18, 20, 22, 24]])

# %%
y - x
# Out:
# array([[8, 8, 8, 8],
#        [8, 8, 8, 8]])

# %%
x * y
# Out:
# array([[  9,  20,  33,  48],
#        [ 65,  84, 105, 128]])

# %%
y / x
# Out:
# array([[9.        , 5.        , 3.66666667, 3.        ],
#        [2.6       , 2.33333333, 2.14285714, 2.        ]])

# %%
x**2
# Out:
# array([[ 1,  4,  9, 16],
#        [25, 36, 49, 64]])

# %%
y**(1/2)
# Out:
# array([[3.        , 3.16227766, 3.31662479, 3.46410162],
#        [3.60555128, 3.74165739, 3.87298335, 4.        ]])

# %%
x**(1/3)
# Out:
# array([[1.        , 1.25992105, 1.44224957, 1.58740105],
#        [1.70997595, 1.81712059, 1.91293118, 2.        ]])

# %%
arr = np.random.randn(5, 4)
arr
# Out:
# array([[-1.02548411, -0.30449412, -0.73461566, -0.18853514],
#        [-2.51752653, -0.30917548,  2.65961865, -2.01878319],
#        [-1.78194483, -1.80507703,  0.01726981,  1.05519493],
#        [ 1.74420908,  0.30751988,  0.73760384,  0.49230511],
#        [ 0.78150599, -0.42730079, -1.34692518,  0.52286444]])

# %%
np.sum(arr) # sum() function
# Out:
# -4.141770342129021

# %%
np.sum(arr, axis=0)
# Out:
# array([-2.7992404 , -2.53852754,  1.33295145, -0.13695385])

# %%
np.sum(arr, axis=1)
# Out:
# array([-2.25312904, -2.18586655, -2.51455712,  3.28163791, -0.46985554])

# %%
np.mean(arr) # mean() function
# Out:
# -0.20708851710645107

# %%
np.mean(arr, axis=0)
# Out:
# array([-0.55984808, -0.50770551,  0.26659029, -0.02739077])

# %%
np.mean(arr, axis=1)
# Out:
# array([-0.56328226, -0.54646664, -0.62863928,  0.82040948, -0.11746389])

# %%
arr1 = np.arange(6)
arr1
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
np.cumsum(arr1)
# Out:
# array([ 0,  1,  3,  6, 10, 15])

# %%
n = np.arange(1, 7).reshape(2, 3)
n
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
m = np.arange(8, 14).reshape(3, 2)
m
# Out:
# array([[ 8,  9],
#        [10, 11],
#        [12, 13]])

# %%
np.dot(n, m) # dot function = x * y
# Out:
# array([[ 64,  70],
#        [154, 169]])

# %%
np.dot(m, n) # dot function = y * x
# Out:
# array([[ 44,  61,  78],
#        [ 54,  75,  96],
#        [ 64,  89, 114]])

# %%
# Liner Algebra
from numpy.linalg import inv
