# %%
import numpy as np

# %%
names = np.array(['Sarvar', 'Nodir', 'Shokir', 'Sardor', 'Timur', 'Nodir', 'Sarvar'])
np.unique(names)
# Out:
# array(['Nodir', 'Sardor', 'Sarvar', 'Shokir', 'Timur'], dtype='<U6')

# %%
arr1 = np.array([6, 0, 0, 2, 3, 5, 6])
arr2 = np.array([0, 2, 3])

# %%
np.in1d(arr1, arr2)
# Out:
# array([False,  True,  True,  True,  True, False, False])

# %%
names1 = np.array(['Sarvar', 'Nodir', 'Shokir', 'Sardor', 'Timur', 'Nodir', 'Sarvar'])
names2 = np.array(['Sarvar', 'Nodir', 'Bahodir', 'Sardor', 'Komil', 'Nodir', 'Sarvar'])

# %%
np.setdiff1d(names1, names2)
# Out:
# array(['Shokir', 'Timur'], dtype='<U6')

# %%
np.setdiff1d(names2, names1)
# Out:
# array(['Bahodir', 'Komil'], dtype='<U7')
