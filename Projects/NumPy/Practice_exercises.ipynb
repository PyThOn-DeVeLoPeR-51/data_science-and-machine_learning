# %%
# First exercise
def one_dim(n):
  arr = []
  num = 0
  if n>0 and n%2 == 0:
    while num<n:
      arr.append(num)
      num += 1
  return arr

my_array = one_dim(4)
print(my_array)
# Out:
# [0, 1, 2, 3]

# %%
# Second exercise
def one_dim(n, m):
  arr = [[], []]
  num = 0
  if n>0 and n%2 == 0:
    while num<n:
      arr.append(num)
      num += 1
  return arr

# %%
import numpy as np

# %%
a = np.array([[1, 2], [3, 4]])
print(a.itemsize)
# Out:
# 8
