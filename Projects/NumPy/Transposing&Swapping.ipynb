# %%
import numpy as np

# %%
A = np.array(range(6)).reshape(3, 2)
A
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
A.T # Transpose massive AT
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
A
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
A.swapaxes(1,0)
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %%
np.dot(A, A.T) #AAT
# Out:
# array([[ 1,  3,  5],
#        [ 3, 13, 23],
#        [ 5, 23, 41]])
